# %%
import pandas as pd
import numpy as np
import simpy
import random
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel(r'C:\Users\DELL\Desktop\Python\SIMPY\Resultado\Reultado terceira opção.xlsx')

# %%
df
# Out:
#      Unnamed: 0  Peças produzidas     Lucro       IROG
# 0             0             42811  569911.5  89.591982
# 1             1             41669  561704.5  87.069444
# 2             2             41954  546196.0  87.672036
# 3             3             42652  531235.0  89.098667
# 4             4             42899  548162.5  89.648974
# ..          ...               ...       ...        ...
# 995         995             43168  603718.0  90.156958
# 996         996             42094  536893.0  87.953202
# 997         997             41651  525337.5  87.044359
# 998         998             43073  537961.5  90.077876
# 999         999             41692  578736.0  87.375968
#
# [1000 rows x 4 columns]

# %%
sns.histplot(df.IROG, kde=True)
plt.title('IROG em 1000 testes')
plt.xlabel('IROG')
plt.savefig('IROG3.png', format='png')
plt.show()

# %%
sns.histplot(df.Lucro, kde=True)
plt.title('Lucro em 1000 testes')
plt.xlabel('Lucro')
plt.savefig('Lucro3.png', format='png')
plt.show()

# %%
sns.histplot(df['Peças produzidas'][df['Peças produzidas']>39000], kde=True)
plt.title('Peças produzidas por mês em 1000 testes')
plt.xlabel('Peças produzidas')
plt.savefig('Peças produzidas3.png', format='png')
plt.show()
